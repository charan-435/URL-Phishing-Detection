# %%
import os

# see what's inside
for root, dirs, files in os.walk("/kaggle/input/datasets/charanponaganti/my-cnn-project/URL-Phishing-Detecttion"):
    dirs[:] = [d for d in dirs if d != "__pycache__"]
    level = root.replace("/kaggle/input/datasets/charanponaganti/my-cnn-project/URL-Phishing-Detecttion", "").count(os.sep)
    indent = " " * 2 * level
    print(f"{indent}{os.path.basename(root)}/")
    for f in files:
        print(f"{indent}  {f}")
# Out:
# URL-Phishing-Detecttion/
#   evaluate.py
#   DEPHIDES_Deep_Learning_Based_Phishing_Detection_System.pdf
#   README.md
#   summary.py
#   requirements.txt
#   feature_extraction.py
#   scripts/
#     train_cnn.py
#     train_rnn.py
#     build_char_index.py
#     train_brnn.py
#     feature_extraction.py
#     train_att.py
#   dataset/
#     char_index
#     val/
#       val.txt
#     test/
#       script.py
#       small_test.txt
#       test.txt
#     train/
#       script.py
#       train.txt
#       small_train.txt
#   models/
#     feature_extraction.py
#     rnn/
#       rnn_complex.py
#       rnn_base.py
#     brnn/
#       brnn_complex.py
#       brnn_base.py
#     cnn/
#       cnn_base.py
#       cnn_complex.py
#     ann/
#       ann.py
#       model_tokenisation/
#         ann_tokenisation.py
#     att/
#       att_base.py
#       att_complex.py
#   test_results/
#     baseline/
#       cnn_complex/
#         model_summary.txt
#         char_embeddings.json
#         floyd_command.txt
#         model.json
#   .git/
#     COMMIT_EDITMSG
#     config
#     packed-refs
#     FETCH_HEAD
#     ORIG_HEAD
#     HEAD
#     index
#     description
#     info/
#       exclude
#     refs/
#       heads/
#         kaisen7
#         main
#       remotes/
#         origin/
#           charan
#           kaisen7
#           HEAD
#           main
#     hooks/
#       pre-merge-commit.sample
#       prepare-commit-msg.sample
#       update.sample
#       pre-push.sample
#       pre-rebase.sample
#       pre-applypatch.sample
#       push-to-checkout.sample
#       pre-commit.sample
#       commit-msg.sample
#       post-update.sample
#       pre-receive.sample
#       fsmonitor-watchman.sample
#       applypatch-msg.sample
#       sendemail-validate.sample
#     logs/
#       HEAD
#       refs/
#         heads/
#           kaisen7
#           main
#         remotes/
#           origin/
#             charan
#             kaisen7
#             HEAD
#             main
#     objects/
#       d8/
#         6d9ae4a03ec8387070f663154cb690bafe7384
#       17/
#         299aef546ba80da933a9908014a81a4c7c3ebe
#       19/
#         5b60d6966dbf5e8816d8429c9a23290ba5a4ad
#       8f/
#         f5c49205c5c02a8814f942f855013386980bbb
#       cf/
#         ab020eb566bf40103aac78a954bc58addd8b8c
#       b8/
#         17be90fc195c2cc85779be882e1c986d1b1778
#         843b755ac0b1c452a5e31d48be69d3be540890
#         7a8f4f1040d02f488c331f0391955c733719e4
#       92/
#         4d77a06b7d4e1105f3b0ac29d83cb7191545a3
#       b2/
#         4e368d25c6737c0e62112c3e8b70fef8d5e91b
#       5b/
#         b43cb1f1fb5f4a1d3d9d87ed77a8f7c73e60f5
#       07/
#         8e6628f76d99b472c637cb3c883ae72f336baa
#         bc8aed2d36995fc914aff3487c7501f3ef43c0
#       24/
#         935e4a97a92a6ad6d5a504f82ca6c6ab4da13d
#         6827244c55702e8f04ad47ac5e4328847c6216
#       93/
#         f7c1ea5a5259ac98ed829f51427c9125f4855c
#       2a/
#         f112cb5fa14fac96a634bcfff4cfe5446b956b

# %%
os.chdir("/kaggle/input/datasets/charanponaganti/my-cnn-project/URL-Phishing-Detecttion")

# %%
import shutil, os

# copy entire project to writable location
shutil.copytree(
    "/kaggle/input/datasets/charanponaganti/my-cnn-project/URL-Phishing-Detecttion",
    "/kaggle/working/project"
)

# set as working directory
os.chdir("/kaggle/working/project")
print(os.getcwd())
# Out:
# /kaggle/working/project

# %%
# !python evaluate.py --category baseline --model cnn_complex
# Out:
# 2026-04-10 10:16:02.801302: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775816163.007115     102 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775816163.073761     102 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775816163.525084     102 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775816163.525139     102 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775816163.525143     102 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775816163.525147     102 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [evaluate] Output directory: test_results/baseline/cnn_complex
# [FeatureExtractor] Loaded 364199 URLs (0 skipped) from dataset/train/train.txt
# [FeatureExtractor] Sequences shape: (364199, 512)
# [FeatureExtractor] Loaded 51509 URLs (1 skipped) from dataset/test/test.txt
# [FeatureExtractor] Sequences shape: (51509, 512)
# [CnnComplex] voc_size: 70
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# I0000 00:00:1775816191.787547     102 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1775816191.793511     102 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775816195.964757     136 service.cc:152] XLA service 0x7d55c4005850 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775816195.964818     136 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1775816195.964831     136 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1775816196.765422     136 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1775816203.227222     136 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 96s 9ms/step - accuracy: 0.8797 - loss: 0.3014 - val_accuracy: 0.9523 - val_loss: 0.1239
# Epoch 2/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 78s 9ms/step - accuracy: 0.9462 - loss: 0.1383 - val_accuracy: 0.9609 - val_loss: 0.0986
# Epoch 3/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 78s 9ms/step - accuracy: 0.9552 - loss: 0.1189 - val_accuracy: 0.9632 - val_loss: 0.0931
# Epoch 4/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 78s 9ms/step - accuracy: 0.9595 - loss: 0.1063 - val_accuracy: 0.9652 - val_loss: 0.0924
# Epoch 5/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 78s 9ms/step - accuracy: 0.9623 - loss: 0.0998 - val_accuracy: 0.9671 - val_loss: 0.0851
# Epoch 6/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 78s 9ms/step - accuracy: 0.9636 - loss: 0.0943 - val_accuracy: 0.9656 - val_loss: 0.0890
# Epoch 7/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 79s 9ms/step - accuracy: 0.9651 - loss: 0.0922 - val_accuracy: 0.9699 - val_loss: 0.0788
# Epoch 8/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 78s 9ms/step - accuracy: 0.9667 - loss: 0.0869 - val_accuracy: 0.9691 - val_loss: 0.0820
# Epoch 9/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 79s 9ms/step - accuracy: 0.9679 - loss: 0.0848 - val_accuracy: 0.9713 - val_loss: 0.0779
# Epoch 10/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 79s 9ms/step - accuracy: 0.9683 - loss: 0.0828 - val_accuracy: 0.9708 - val_loss: 0.0773
# [evaluate] Running inference on test set...
#               precision    recall  f1-score   support
#
#     phishing       0.98      0.96      0.97     22977
#   legitimate       0.97      0.98      0.97     28532
#
#     accuracy                           0.97     51509
#    macro avg       0.97      0.97      0.97     51509
# weighted avg       0.97      0.97      0.97     51509
#
# [evaluate] All results saved to: test_results/baseline/cnn_complex
# [evaluate] Test accuracy: 0.9707
# [evaluate] Training time: 801.6s

# %%
# !python evaluate.py --category baseline --model rnn_base
# Out:
# 2026-04-10 10:31:00.798660: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775817060.823961    2008 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775817060.832182    2008 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775817060.851270    2008 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775817060.851295    2008 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775817060.851299    2008 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775817060.851302    2008 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [evaluate] Output directory: test_results/baseline/rnn_base
# [FeatureExtractor] Loaded 364199 URLs (0 skipped) from dataset/train/train.txt
# [FeatureExtractor] Sequences shape: (364199, 512)
# [FeatureExtractor] Loaded 51509 URLs (1 skipped) from dataset/test/test.txt
# [FeatureExtractor] Sequences shape: (51509, 512)
# [RnnBase] voc_size: 70
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# I0000 00:00:1775817073.110639    2008 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1775817073.115788    2008 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Epoch 1/10
# I0000 00:00:1775817076.588647    2042 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 208s 22ms/step - accuracy: 0.8794 - loss: 0.2787 - val_accuracy: 0.9450 - val_loss: 0.1397
# Epoch 2/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 204s 22ms/step - accuracy: 0.9517 - loss: 0.1224 - val_accuracy: 0.9607 - val_loss: 0.1004
# Epoch 3/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 204s 22ms/step - accuracy: 0.9670 - loss: 0.0855 - val_accuracy: 0.9691 - val_loss: 0.0811
# Epoch 4/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 204s 22ms/step - accuracy: 0.9737 - loss: 0.0690 - val_accuracy: 0.9696 - val_loss: 0.0779
# Epoch 5/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 204s 22ms/step - accuracy: 0.9773 - loss: 0.0593 - val_accuracy: 0.9720 - val_loss: 0.0726
# Epoch 6/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 203s 22ms/step - accuracy: 0.9805 - loss: 0.0519 - val_accuracy: 0.9736 - val_loss: 0.0691
# Epoch 7/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 206s 23ms/step - accuracy: 0.9827 - loss: 0.0461 - val_accuracy: 0.9715 - val_loss: 0.0742
# Epoch 8/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 207s 23ms/step - accuracy: 0.9845 - loss: 0.0417 - val_accuracy: 0.9743 - val_loss: 0.0711
# Epoch 9/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 207s 23ms/step - accuracy: 0.9858 - loss: 0.0376 - val_accuracy: 0.9739 - val_loss: 0.0747
# Epoch 10/10
# 9105/9105 ━━━━━━━━━━━━━━━━━━━━ 210s 23ms/step - accuracy: 0.9871 - loss: 0.0348 - val_accuracy: 0.9733 - val_loss: 0.0749
# [evaluate] Running inference on test set...
#               precision    recall  f1-score   support
#
#     phishing       0.98      0.96      0.97     22977
#   legitimate       0.97      0.99      0.98     28532
#
#     accuracy                           0.97     51509
#    macro avg       0.97      0.97      0.97     51509
# weighted avg       0.97      0.97      0.97     51509
#
# [evaluate] All results saved to: test_results/baseline/rnn_base
# [evaluate] Test accuracy: 0.9737
# [evaluate] Training time: 2057.8s

# %%
import shutil

# zip the entire working directory
shutil.make_archive("/kaggle/working/results", "zip", "/kaggle/working/project/test_results")
print("Done! Download results.zip from the Output tab")
# Out:
# Done! Download results.zip from the Output tab
