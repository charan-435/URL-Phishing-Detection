# %%
import os

# see what's inside
for root, dirs, files in os.walk("/kaggle/input/datasets/charanponaganti/my-cnn-project/URL-Phishing-Detecttion"):
    dirs[:] = [d for d in dirs if d != "__pycache__"]
    level = root.replace("/kaggle/input/datasets/charanponaganti/my-cnn-project/URL-Phishing-Detecttion", "").count(os.sep)
    indent = " " * 2 * level
    print(f"{indent}{os.path.basename(root)}/")
    for f in files:
        print(f"{indent}  {f}")
# Out:
# URL-Phishing-Detecttion/
#   evaluate.py
#   DEPHIDES_Deep_Learning_Based_Phishing_Detection_System.pdf
#   README.md
#   summary.py
#   requirements.txt
#   feature_extraction.py
#   scripts/
#     train_cnn.py
#     train_rnn.py
#     build_char_index.py
#     train_brnn.py
#     feature_extraction.py
#     train_att.py
#   dataset/
#     char_index
#     val/
#       val.txt
#     test/
#       script.py
#       small_test.txt
#       test.txt
#     train/
#       script.py
#       train.txt
#       small_train.txt
#   models/
#     feature_extraction.py
#     rnn/
#       rnn_complex.py
#       rnn_base.py
#     brnn/
#       brnn_complex.py
#       brnn_base.py
#     cnn/
#       cnn_base.py
#       cnn_complex.py
#     ann/
#       ann.py
#       model_tokenisation/
#         ann_tokenisation.py
#     att/
#       att_base.py
#       att_complex.py
#   test_results/
#     baseline/
#       cnn_complex/
#         model_summary.txt
#         char_embeddings.json
# ...

# %%
os.chdir("/kaggle/input/datasets/charanponaganti/my-cnn-project/URL-Phishing-Detecttion")

# %%
import shutil, os

# copy entire project to writable location
shutil.copytree(
    "/kaggle/input/datasets/charanponaganti/my-cnn-project/URL-Phishing-Detecttion",
    "/kaggle/working/project"
)

# set as working directory
os.chdir("/kaggle/working/project")
print(os.getcwd())
# Out:
# /kaggle/working/project

# %%
# !python evaluate.py --category baseline --model cnn_base --epochs 5
# Out:
# 2026-04-18 07:22:58.923515: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776496978.948026     395 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776496978.956604     395 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776496978.977065     395 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python evaluate.py --category baseline --model rnn_base --epochs 5
# Out:
# 2026-04-18 07:27:26.440753: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776497246.466056    1098 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776497246.474080    1098 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776497246.494038    1098 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python evaluate.py --category baseline --model brnn_base --epochs 5
# Out:
# 2026-04-18 07:44:50.598309: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776498290.625727    3290 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776498290.634487    3290 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776498290.655494    3290 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python evaluate.py --category baseline --model att_base --epochs 5
# Out:
# 2026-04-18 08:17:10.730618: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776500230.759797    7184 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776500230.769020    7184 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776500230.792294    7184 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import shutil

# zip the entire working directory
shutil.make_archive("/kaggle/working/results", "zip", "/kaggle/working/project/test_results")
print("Done! Download results.zip from the Output tab")
# Out:
# Done! Download results.zip from the Output tab
